# %%
from sklearn.metrics import classification_report
import numpy as np
import tensorflow as tf
import json

# %%
base_path = '/data/processed/'
dataset = 'gtzan_False_noSeperation_LibrosaCPUSTFT'
dataset_path = base_path + dataset
metadata = json.load(open(f'{dataset_path}/metadata.json'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-49e3e3f92e8b> in <module>
#       2 dataset = 'gtzan_False_noSeperation_LibrosaCPUSTFT'
#       3 dataset_path = base_path + dataset
# ----> 4 metadata = json.load(open(f'{self._dataset_path}/metadata.json'))
#
# NameError: name 'self' is not defined

# %%
model = tf.keras.models.load_model('./logs/ParallelCRNN/gtzan_False_noSeperation_LibrosaCPUSTFT/19-06-2021-11-22-50/trained_model')
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:1045: UserWarning: model.parallel_crnn is not loaded, but a Lambda layer uses it. It may cause errors.
#   , UserWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c5d5094f3f4d> in <module>
# ----> 1 model = tf.keras.models.load_model('./logs/ParallelCRNN/gtzan_False_noSeperation_LibrosaCPUSTFT/19-06-2021-11-22-50/trained_model')
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     185     if isinstance(filepath, six.string_types):
#     186       loader_impl.parse_saved_model(filepath)
# --> 187       return saved_model_load.load(filepath, compile, options)
#     188
#     189   raise IOError(
#
# ...
